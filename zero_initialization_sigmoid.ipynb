# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

# %%
X,y = make_moons(n_samples=250, noise=0.3, random_state=42)

# %%
plt.scatter(X[:,0],X[:,1], c=y, s=100)
plt.show()

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(2,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 2)                 6
#
#  dense_5 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set parameters to 0
model.get_weights()
# Out:
# [array([[ 0.12874305,  1.1253425 ],
#         [ 1.2072486 , -1.1971864 ]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.46088725],
#         [ 0.04279721]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
initial_weights = model.get_weights()

# %%
initial_weights[0] = np.zeros(model.get_weights()[0].shape)
initial_weights[1] = np.zeros(model.get_weights()[1].shape)
initial_weights[2] = np.zeros(model.get_weights()[2].shape)
initial_weights[3] = np.zeros(model.get_weights()[3].shape)

# %%
model.set_weights(initial_weights)

# %%
model.get_weights()
# Out:
# [array([[0., 0.],
#         [0., 0.]], dtype=float32), array([0., 0.], dtype=float32), array([[0.],
#         [0.]], dtype=float32), array([0.], dtype=float32)]

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history = model.fit(X,y,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 29ms/step - loss: 0.6932 - accuracy: 0.4650 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 2/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 3/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 4/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 5/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 6/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 7/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 8/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6930 - val_accuracy: 0.5200
# Epoch 9/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6930 - val_accuracy: 0.5200
# Epoch 10/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6930 - val_accuracy: 0.5200
# Epoch 11/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 12/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 13/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 14/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 15/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6930 - val_accuracy: 0.5200
# Epoch 16/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6930 - val_accuracy: 0.5200
# Epoch 17/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6930 - val_accuracy: 0.5200
# Epoch 18/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 19/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 20/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 21/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6932 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 22/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6931 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 23/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6931 - accuracy: 0.4950 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 24/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6932 - accuracy: 0.4850 - val_loss: 0.6932 - val_accuracy: 0.4800
# Epoch 25/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6932 - val_accuracy: 0.4800
# Epoch 26/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6932 - val_accuracy: 0.4800
# Epoch 27/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6932 - val_accuracy: 0.4800
# Epoch 28/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6932 - val_accuracy: 0.4800
# Epoch 29/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6932 - val_accuracy: 0.4800
# Epoch 30/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6932 - val_accuracy: 0.4800
# Epoch 31/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6932 - val_accuracy: 0.4800
# Epoch 32/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 33/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 34/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 35/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 36/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 37/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 38/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 39/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 40/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 41/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 42/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 43/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 44/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 45/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 46/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 47/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 48/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 49/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 50/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 51/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 52/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 53/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 54/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 55/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 56/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 57/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 58/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 59/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 60/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 61/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 62/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 63/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 64/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 65/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 66/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 67/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 68/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 69/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 70/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 71/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 72/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 73/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 74/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 75/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 76/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 77/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 78/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 79/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 80/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 81/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6933 - val_accuracy: 0.4800
# Epoch 82/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 83/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 84/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6934 - val_accuracy: 0.4800
# Epoch 85/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 86/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 87/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 88/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 89/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 90/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 91/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 92/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 93/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 94/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 95/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 96/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 97/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 98/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 99/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 100/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5050 - val_loss: 0.6935 - val_accuracy: 0.4800

# %%
model.get_weights()
# Out:
# [array([[0., 0.],
#         [0., 0.]], dtype=float32), array([0., 0.], dtype=float32), array([[0.],
#         [0.]], dtype=float32), array([-0.01462409], dtype=float32)]

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X,y, clf=model, legend=2)
# Out:
# 3888/3888 [==============================] - 6s 1ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-401d246388f7> in <module>
#       1 from mlxtend.plotting import plot_decision_regions
# ----> 2 plot_decision_regions(X,y, clf=model, legend=2)
#
# /usr/local/lib/python3.8/dist-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     242                antialiased=True)
#     243
# --> 244     ax.axis(xmin=xx.min(), xmax=xx.max(), y_min=yy.min(), y_max=yy.max())
#     245
#     246     # Scatter training data samples
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in axis(self, emit, *args, **kwargs)
#    2097             self.set_ylim(ymin, ymax, emit=emit, auto=yauto)
#    2098         if kwargs:
# -> 2099             raise TypeError(f"axis() got an unexpected keyword argument "
#    2100                             f"'{next(iter(kwargs))}'")
#    2101         return (*self.get_xlim(), *self.get_ylim())
#
# TypeError: axis() got an unexpected keyword argument 'y_min'
